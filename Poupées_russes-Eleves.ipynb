# %% [markdown]
# <h1 id="Les-poup&eacute;es-russes">L<span style="color: #e03e2d;">e</span>s <span style="color: #e03e2d;">p</span>o<span style="color: #e03e2d;">u</span>p<span style="color: #e03e2d;">&eacute;</span>e<span style="color: #e03e2d;">s</span> <span style="background-color: #ffffff;">r<span style="color: #e03e2d;">u</span>s<span style="color: #e03e2d;">s</span>e<span style="color: #e03e2d;">s</span></span></h1>

# %% [markdown]
# ## Partie 1 : Une poupée ?

# %% [markdown]
# Un objet de type Matrioshka représente une poupée russe sur laquelle est inscrit un message (une valeur numérique ou une chaîne de caractères par exemple).
#
# ![poupee.PNG](attachment:poupee.PNG)
#
# L'attribut suivante désigne pour l'instant n'importe quel type de  valeur.
#
# On considère la classe suivante :

# %%
class Matrioshka:
	def __init__(self, valeur, poupeerusse):
		self.message = valeur
		self.suivante = poupeerusse

# %% [markdown]
# ### Exercice 1
#
# 1. Créer une poupée nommée poupee_1 avec comme attribut message l'entier 12 et commme attribut suivante "yo".
#
# ![Capture2.PNG](attachment:Capture2.PNG)

# %%
# Ecrire ici.

# %% [markdown]
# 2. Afficher l'attribut message

# %%
# Ecrire ici.

# %% [markdown]
# 3. Afficher l'attribut suivante

# %%
# Ecrire ici.

# %% [markdown]
# ### Exercice 2
#
# 1. Créer une poupée nommée poupee_2 avec comme attribut message l'entier 23 et commme attribut suivante None.
# ![Capture3.PNG](attachment:Capture3.PNG)

# %%
# Ecrire ici.

# %% [markdown]
# 2. Afficher l'attribut message

# %%
# Ecrire ici.

# %% [markdown]
# 3. Tester si l'attribut suivante est None

# %%
# Ecrire ici.

# %% [markdown]
# ### Exercice 3
#
# 1. Créer une poupée nommée poupee_3 avec comme attribut message l'entier 42 et commme attribut suivante poupée_2.
#
# ![Capture4.PNG](attachment:Capture4.PNG)
#
# ![Capture5.PNG](attachment:Capture5.PNG)

# %%
# Ecrire ici.

# %% [markdown]
# 2. Afficher l'attribut message

# %%
# Ecrire ici.

# %% [markdown]
# 3. Afficher l'attribut suivante puis afficher le type de l'attribut suivante. Qu'en pensez_vous ?

# %%
# Ecrire ici.

# %% [markdown]
# 4. Afficher l'attribut message de poupee_2 de deux façons différentes.

# %%
# Ecrire ici.

# %%
# Ecrire ici.

# %% [markdown]
# ### Exercice 4
#
# 1. Créer une poupée nommée poupee_4 avec comme attribut message l'entier 72 et commme attribut suivante Matrioshka(42,None).![Capture1.PNG](attachment:Capture1.PNG)

# %%
# Ecrire ici.

# %% [markdown]
# 2. Afficher l'attribut message

# %%
# Ecrire ici.

# %% [markdown]
# 3. Afficher l'attribut suivante de Poupee_4.  Qu'en pensez_vous ?

# %%
# Ecrire ici.

# %% [markdown]
# 4. Afficher la valeur 42

# %%
# Ecrire ici.

# %% [markdown]
# ##  Partie 2 : Emboitement

# %% [markdown]
# Un objet de type Matrioshka représente une poupée russe sur laquelle est inscrit un message (une valeur numérique ou une chaîne de caractères par exemple).
#
# ![matrioshka.png](attachment:matrioshka.png)
#
# L'attribut suivante désigne la poupée de hauteur juste inférieure, la première visible à l'intérieur de notre matrioshka lorsqu'on l'ouvre. Cet attribut suivante vaudra None s'il s'agit de la poupée la plus petite.
#
# Lorsqu'on emboîte les poupées l'une dans l'autre, on ne voit donc que le message de la poupée visible qui contient les autres poupées.
#
# Définir une classe **Emboitement**.
#
# Les attributs :
#
# * hauteur : nombre de poupées emboîtées (initialisation à 0).
# * sommet : la seule poupée visible, c'est à dire celle qui contient toutes les autres (initialisation à None).
#
# Les méthodes :
#
# * emboiter(self, valeur) : cette méthode emboite l'emboitement actuel dans une plus grande poupée dont le message sera égal à valeur.
# * deboiter : cette méthode supprime la poupée de plus haut niveau, la poupée de niveau juste en-dessous deviendra donc la poupée visible.
# * valeurVisible : renvoie la valeur inscrite sur la poupée visible.
# * estVide : renvoie True s'il n'y a plus de poupée, False sinon.
# * afficher : une méthode pour afficher la liste des valeurs (valeurs des attributs "message" des poupées emboîtées) dans tout l'emboîtement

# %%
# On rappelle la classe Matrioshka
class Matrioshka:
	def __init__(self, valeur, poupeerusse):
		self.message = valeur
		self.suivante = poupeerusse

# %% [markdown]
# 1. Exemples d’utilisation de cette classe :
#
# e = Emboitement()
# ![emboitement1.PNG](attachment:emboitement1.PNG)
# e.emboiter(3)
# ![emboitement2.PNG](attachment:emboitement2.PNG)
# e.emboiter(5)
# ![emboitement3.PNG](attachment:emboitement3.PNG)
# e.afficher()
# ![emboitement4.PNG](attachment:emboitement4.PNG)
#
# e.deboiter()
#
# print("\nValeur vue après un déboitement :" , e.valeurVisible())
#
# ![emboitement6.PNG](attachment:emboitement6.PNG)
#
# e.deboiter()
#
# print("\nValeur vue après un second déboitement :" , e.valeurVisible())
#
# ![emboitement7.PNG](attachment:emboitement7.PNG)
#
# print()
#
# e.afficher()
#
# ![emboitement8.PNG](attachment:emboitement8.PNG)

# %% [markdown]
# Nous allons construire pas à pas la classe **Emboitement** ci-dessous.
#
# Les méthodes  __init__() et afficher() sont données.
#
# 1. Construire la méthode estVide(). On pourra utiliser l'attribut hauteur.
#
#
# 2. Construire la méthode valeurVisible(). Si l'emboitement n'est pas vide, c'est ...
#
#
# 4. Construire la méthode emboiter().
#
# On pourra suivre les conseils suivants.
# * on récupère le sommet (soit none soit une poupée).
# * on crée un nouveau somment qui est une poupée d'une certaine valeur et de valeur suivante le sommet récupéré.
# * on augmente la valeur de l'attribut hauteur de 1.
#
#
# 5. Compléter la méthode deboiter().
#
#     	def deboiter(self):
# 		if not self.estVide():
# 			s = ...
# 			self.sommet = ...
# 			self.hauteur ...

# %%
class Emboitement:

	def __init__(self):
		self.hauteur = 0 # nombre de matrioshkas emboîtées
		self.sommet =  None # matrioska visible

	def emboiter(self, valeur):
		...

	def deboiter(self):
		...

	def valeurVisible(self):
		...

	def estVide(self):
		...

	def afficher(self):
		print("\nLes messages de l'emboîtement : ")
		poupee = self.sommet
		while poupee != None:
			print("|\t" + str(poupee.message) + "\t|")
			poupee = poupee.suivante

# %% [markdown]
# Exemples d’utilisation de cette classe :
#
# e = Emboitement()
#
# e.emboiter(3)
#
# e.emboiter(5)
#
# e.emboiter(1)
#
# e.emboiter(12)
#
# e.afficher()
#
# e.deboiter()
#
# print("\nValeur vue après un déboitement :" , e.valeurVisible())
#
# e.deboiter()
#
# print("\nValeur vue après un second déboitement :" , e.valeurVisible())
#
# print()
#
# e.afficher()

# %% [markdown]
# ![emboitement9.PNG](attachment:emboitement9.PNG)
